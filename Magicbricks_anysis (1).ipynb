# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import scipy

# %%
df=pd.read_csv('magicbricks_Ready_to_Move_Flats_50_Pages.csv')

# %%
df.head()
# Out:
#     Area Property Furnished Status    Bathroom                       Society  \
# 0  807.0    2 BHK      Unfurnished  Bathroom 2            Sudarshan Paradise
# 1  973.0    3 BHK      Unfurnished  Bathroom 3  Shapoorji Pallonji Sensorium
# 2  640.0    2 BHK              NaN  Bathroom 2                  Forest Hills
# 3  894.0    2 BHK              NaN  Bathroom 2                Kundan Espacio
# 4  560.0    1 BHK              NaN  Bathroom 1            Tarangan Apartment
#
#      Price        Floor         Status
# 0   65 Lac          NaN  Ready to Move
# 1  1.32 Cr          NaN            NaN
# 2   37 Lac   7 out of 7  Ready to Move
# 3  1.20 Cr  3 out of 13  Ready to Move
# 4   90 Lac   2 out of 3  Ready to Move

# %%
df.shape
# Out:
# (1500, 8)

# %%
df.isnull().sum()
# Out:
# Area                 1
# Property             0
# Furnished Status    23
# Bathroom             1
# Society              5
# Price                0
# Floor               18
# Status               2
# dtype: int64

# %%
df.describe()
# Out:
#               Area
# count  1499.000000
# mean    602.056704
# std     239.551799
# min      87.000000
# 25%     438.000000
# 50%     562.000000
# 75%     702.000000
# max    3096.000000

# %%
# so the property and price don't have missing value
df.dropna(axis=1)
# Out:
#      Property    Price
# 0       2 BHK   65 Lac
# 1       3 BHK  1.32 Cr
# 2       2 BHK   37 Lac
# 3       2 BHK  1.20 Cr
# 4       1 BHK   90 Lac
# ...       ...      ...
# 1495    2 BHK   80 Lac
# 1496    1 BHK   30 Lac
# 1497    1 BHK   40 Lac
# 1498    1 BHK   32 Lac
# 1499    1 BHK   22 Lac
#
# [1500 rows x 2 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df = df.dropna(subset=['Floor'])

# %%
df = df.dropna(subset=['Status'])

# %%
df = df.dropna(subset=['Society'])

# %%
df = df.dropna(subset=['Bathroom'])

# %%
df = df.dropna(subset=['Furnished Status'])

# %%
df = df.dropna(subset=['Area'])

# %%
df
# Out:
#        Area Property Furnished Status    Bathroom                 Society  \
# 7     392.0    1 BHK      Unfurnished  Bathroom 1  Ishwar River Residency
# 8     471.0    1 BHK      Unfurnished  Bathroom 1        Kohinoor Majesty
# 9     525.0    1 BHK      Unfurnished  Bathroom 1   Sancheti Pratik Nagar
# 11    517.0    1 BHK      Unfurnished  Bathroom 1                 Blossom
# 13    645.0    1 BHK      Unfurnished  Bathroom 2              Raga Homes
# ...     ...      ...              ...         ...                     ...
# 1495  723.0    2 BHK   Semi-Furnished  Bathroom 2          Tropical Palms
# 1496  403.0    1 BHK   Semi-Furnished  Bathroom 1         Lotus Apartment
# 1497  454.0    1 BHK      Unfurnished  Bathroom 1           Florida Minis
# 1498  491.0    1 BHK      Unfurnished  Bathroom 1          Swaraj Complex
# 1499  299.0    1 BHK      Unfurnished  Bathroom 1          Satyam Heights
#
#          Price         Floor         Status
# 7       32 Lac  12 out of 12  Ready to Move
# 8     21.5 Lac    5 out of 9  Ready to Move
# 9       28 Lac    1 out of 3  Ready to Move
# 11      35 Lac   2 out of 11  Ready to Move
# 13      37 Lac  10 out of 11  Ready to Move
# ...        ...           ...            ...
# 1495    80 Lac   1 out of 15  Ready to Move
# 1496    30 Lac    3 out of 4  Ready to Move
# 1497    40 Lac    2 out of 5  Ready to Move
# 1498    32 Lac    1 out of 7  Ready to Move
# 1499    22 Lac    1 out of 3  Ready to Move
#
# [1455 rows x 8 columns]

# %%
def convert_cr_to_lac_clean(price):
    if isinstance(price, str):
        if 'Cr' in price:
            cr_value = float(price.split()[0])
            lac_value = cr_value * 100
            return f"{lac_value:.0f} Lac"
        elif 'Lac' in price:
            return price
    return price

df['Price'] = df['Price'].apply(convert_cr_to_lac_clean)

# %%
df
# Out:
#        Area Property Furnished Status    Bathroom                 Society  \
# 7     392.0    1 BHK      Unfurnished  Bathroom 1  Ishwar River Residency
# 8     471.0    1 BHK      Unfurnished  Bathroom 1        Kohinoor Majesty
# 9     525.0    1 BHK      Unfurnished  Bathroom 1   Sancheti Pratik Nagar
# 11    517.0    1 BHK      Unfurnished  Bathroom 1                 Blossom
# 13    645.0    1 BHK      Unfurnished  Bathroom 2              Raga Homes
# ...     ...      ...              ...         ...                     ...
# 1495  723.0    2 BHK   Semi-Furnished  Bathroom 2          Tropical Palms
# 1496  403.0    1 BHK   Semi-Furnished  Bathroom 1         Lotus Apartment
# 1497  454.0    1 BHK      Unfurnished  Bathroom 1           Florida Minis
# 1498  491.0    1 BHK      Unfurnished  Bathroom 1          Swaraj Complex
# 1499  299.0    1 BHK      Unfurnished  Bathroom 1          Satyam Heights
#
#          Price         Floor         Status
# 7       32 Lac  12 out of 12  Ready to Move
# 8     21.5 Lac    5 out of 9  Ready to Move
# 9       28 Lac    1 out of 3  Ready to Move
# 11      35 Lac   2 out of 11  Ready to Move
# 13      37 Lac  10 out of 11  Ready to Move
# ...        ...           ...            ...
# 1495    80 Lac   1 out of 15  Ready to Move
# 1496    30 Lac    3 out of 4  Ready to Move
# 1497    40 Lac    2 out of 5  Ready to Move
# 1498    32 Lac    1 out of 7  Ready to Move
# 1499    22 Lac    1 out of 3  Ready to Move
#
# [1455 rows x 8 columns]

# %%
df['Price'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Price'] = df['Price'].str.replace('Lac', '', regex=False).str.strip()

# %%
df
# Out:
#        Area Property Furnished Status    Bathroom                 Society  \
# 7     392.0    1 BHK      Unfurnished  Bathroom 1  Ishwar River Residency
# 8     471.0    1 BHK      Unfurnished  Bathroom 1        Kohinoor Majesty
# 9     525.0    1 BHK      Unfurnished  Bathroom 1   Sancheti Pratik Nagar
# 11    517.0    1 BHK      Unfurnished  Bathroom 1                 Blossom
# 13    645.0    1 BHK      Unfurnished  Bathroom 2              Raga Homes
# ...     ...      ...              ...         ...                     ...
# 1496  403       1    Semi-Furnished        1         Lotus Apartment    30
# 1497  454       1       Unfurnished        1           Florida Minis    40
# 1498  491       1       Unfurnished        1          Swaraj Complex    32
# 1499  299       1       Unfurnished        1          Satyam Heights    22
#
#              Floor         Status
# 7     12 out of 12  Ready to Move
# 8       5 out of 9  Ready to Move
# 9       1 out of 3  Ready to Move
# 11     2 out of 11  Ready to Move
# 13    10 out of 11  Ready to Move
# ...            ...            ...
# 1495   1 out of 15  Ready to Move
# 1496    3 out of 4  Ready to Move
# 1497    2 out of 5  Ready to Move
# 1498    1 out of 7  Ready to Move
# 1499    1 out of 3  Ready to Move
#
# [1455 rows x 8 columns]

# %%
# First, split the 'Floor' column on ' out of '
df[['house_floor', 'building_floor']] = df['Floor'].str.extract(r'(\d+)\s+out of\s+(\d+)')
df=df.dropna(subset=['house_floor'])
df=df.dropna(subset=['building_floor'])
# Convert new columns to numeric
df['house_floor'] = df['house_floor'].astype(int)
df['building_floor'] = df['building_floor'].astype(int)

# %%
df
# Out:
#      Area Property Furnished Status Bathroom                 Society Price  \
# 7     392       1       Unfurnished        1  Ishwar River Residency    32
# 8     471       1       Unfurnished        1        Kohinoor Majesty  21.5
# 9     525       1       Unfurnished        1   Sancheti Pratik Nagar    28
# 11    517       1       Unfurnished        1                 Blossom    35
# 13    645       1       Unfurnished        2              Raga Homes    37
# ...   ...      ...              ...      ...                     ...   ...
# 1495  723       2    Semi-Furnished        2          Tropical Palms    80
# 1496  403       1    Semi-Furnished        1         Lotus Apartment    30
# 1497  454       1       Unfurnished        1           Florida Minis    40
# 1498  491       1       Unfurnished        1          Swaraj Complex    32
# 1499  299       1       Unfurnished        1          Satyam Heights    22
#
#              Floor         Status  house_floor  building_floor
# 7     12 out of 12  Ready to Move           12              12
# 8       5 out of 9  Ready to Move            5               9
# 9       1 out of 3  Ready to Move            1               3
# 11     2 out of 11  Ready to Move            2              11
# 13    10 out of 11  Ready to Move           10              11
# ...            ...            ...          ...             ...
# 1495   1 out of 15  Ready to Move            1              15
# 1496    3 out of 4  Ready to Move            3               4
# 1497    2 out of 5  Ready to Move            2               5
# 1498    1 out of 7  Ready to Move            1               7
# 1499    1 out of 3  Ready to Move            1               3
#
# [1420 rows x 10 columns]

# %%
df=df.rename(columns={"Area": "Area_sqft", "Property": "Property_BHK","house_floor":"House_floor",'Furnished Status':'Furnished_Status'})

# %%
df
# Out:
#      Area_sqft Property_BHK Furnished_Status Bathroom                 Society  \
# 7          392           1       Unfurnished        1  Ishwar River Residency
# 8          471           1       Unfurnished        1        Kohinoor Majesty
# 9          525           1       Unfurnished        1   Sancheti Pratik Nagar
# 11         517           1       Unfurnished        1                 Blossom
# 13         645           1       Unfurnished        2              Raga Homes
# ...        ...          ...              ...      ...                     ...
# 1495       723           2    Semi-Furnished        2          Tropical Palms
# 1496       403           1    Semi-Furnished        1         Lotus Apartment
# 1497       454           1       Unfurnished        1           Florida Minis
# 1498       491           1       Unfurnished        1          Swaraj Complex
# 1499       299           1       Unfurnished        1          Satyam Heights
#
#      Price         Floor         Status  House_floor  building_floor
# 7       32  12 out of 12  Ready to Move           12              12
# 8     21.5    5 out of 9  Ready to Move            5               9
# 9       28    1 out of 3  Ready to Move            1               3
# 11      35   2 out of 11  Ready to Move            2              11
# 13      37  10 out of 11  Ready to Move           10              11
# ...    ...           ...            ...          ...             ...
# 1495    80   1 out of 15  Ready to Move            1              15
# 1496    30    3 out of 4  Ready to Move            3               4
# 1497    40    2 out of 5  Ready to Move            2               5
# 1498    32    1 out of 7  Ready to Move            1               7
# 1499    22    1 out of 3  Ready to Move            1               3
#
# [1420 rows x 10 columns]

# %%
df=df.drop('Floor',axis=1)

# %%
df.dtypes
# Out:
# Area_sqft           object
# Property_BHK        object
# Furnished_Status    object
# Bathroom            object
# Society             object
# Price               object
# Status              object
# House_floor          int64
# building_floor       int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Area_sqft           0
# Property_BHK        0
# Furnished_Status    0
# Bathroom            0
# Society             0
# Price               0
# Status              0
# House_floor         0
# building_floor      0
# dtype: int64

# %%
df['Property_BHK']=df['Property_BHK'].astype(int)
df['Bathroom']=df['Bathroom'].astype(int)
df['House_floor']=df['House_floor'].astype(int)
df['building_floor']=df['building_floor'].astype(int)
df['Price'] = df['Price'].astype(float).astype(int)

# %%
df
# Out:
#      Area_sqft  Property_BHK Furnished_Status  Bathroom  \
# 7          392             1      Unfurnished         1
# 8          471             1      Unfurnished         1
# 9          525             1      Unfurnished         1
# 11         517             1      Unfurnished         1
# 13         645             1      Unfurnished         2
# ...        ...           ...              ...       ...
# 1495       723             2   Semi-Furnished         2
# 1496       403             1   Semi-Furnished         1
# 1497       454             1      Unfurnished         1
# 1498       491             1      Unfurnished         1
# 1499       299             1      Unfurnished         1
#
#                      Society  Price         Status  House_floor  \
# 7     Ishwar River Residency     32  Ready to Move           12
# 8           Kohinoor Majesty     21  Ready to Move            5
# 9      Sancheti Pratik Nagar     28  Ready to Move            1
# 11                   Blossom     35  Ready to Move            2
# 13                Raga Homes     37  Ready to Move           10
# ...                      ...    ...            ...          ...
# 1495          Tropical Palms     80  Ready to Move            1
# 1496         Lotus Apartment     30  Ready to Move            3
# 1497           Florida Minis     40  Ready to Move            2
# 1498          Swaraj Complex     32  Ready to Move            1
# 1499          Satyam Heights     22  Ready to Move            1
#
#       building_floor
# 7                 12
# 8                  9
# 9                  3
# 11                11
# 13                11
# ...              ...
# 1495              15
# 1496               4
# 1497               5
# 1498               7
# 1499               3
#
# [1420 rows x 9 columns]

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(6, 4))
df['Furnished_Status'].value_counts().plot(kind='bar', color='coral')
plt.title('Furnishing Status Distribution')
plt.ylabel('Number of Properties')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.heatmap(df[['Price', 'Area_sqft', 'Property_BHK', 'Bathroom', 'House_floor', 'building_floor']].corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert Price to numeric
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Area_sqft'] = pd.to_numeric(df['Area_sqft'], errors='coerce')

# Price Range Mapping
def map_price_range(price):
    if pd.isna(price):
        return 'Unknown'
    for start in range(0, 280, 30):
        end = start + 30
        if start <= price < end:
            return f'{start}-{end}L'
    return '280L+'

# Area Range Mapping
def map_area_range(area):
    if pd.isna(area):
        return 'Unknown'
    for start in range(0, 1000, 200):
        end = start + 200
        if start <= area < end:
            return f'{start}-{end} sqft'
    return '1000+ sqft'

# Apply Mapping
df['Price_Range'] = df['Price'].map(map_price_range)
df['Area_Range'] = df['Area_sqft'].map(map_area_range)

# Plotting
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Area_sqft', y='Price', hue='Price_Range', palette='coolwarm')
plt.title('Area vs. Price by Price Range')
plt.xlabel('Area (sqft)')
plt.ylabel('Price (Lakh ₹)')
plt.legend(title='Price Range', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['Area_sqft'].max()
# Out:
# 3096

# %%
from pandas.api.types import CategoricalDtype

# Define the correct order for price ranges
price_range_order = [
    '0-30L', '30-60L', '60-90L', '90-120L', '120-150L', '150-180L',
    '180-210L', '210-240L', '240-270L', '270-300L', '280L+'
]

# Set as ordered categorical
price_cat = CategoricalDtype(categories=price_range_order, ordered=True)
df['Price_Range'] = df['Price_Range'].astype(price_cat)

# Now plot
plt.figure(figsize=(7, 4))
sns.boxplot(data=df, x='Bathroom', y='Price_Range', palette='muted')
plt.title('Price Range vs. Number of Bathrooms')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Price Range')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Map price ranges (you already did this part)
def map_price_range(price):
    if pd.isna(price):
        return 'Unknown'
    for start in range(0, 280, 30):
        end = start + 30
        if start <= price < end:
            return f'{start}-{end}L'
    return '280L+'

df['Price_Range'] = df['Price'].map(map_price_range)

# Barplot (Furnished Status vs Average Price)
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='Furnished_Status', y='Price', palette='pastel', estimator='mean')  # 'mean' is default
plt.title('Average Price by Furnishing Status')
plt.xticks(rotation=45)
plt.ylabel('Average Price (Lakh ₹)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.plot(kind='hist', subplots=True, layout=(4, 2), figsize=(10, 10))
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>]],
#       dtype=object)

# %%
df.plot(kind='box', subplots=True, layout=(4, 2), figsize=(10, 10))
# Out:
# Area_sqft            Axes(0.125,0.712609;0.352273x0.167391)
# Property_BHK      Axes(0.547727,0.712609;0.352273x0.167391)
# Bathroom             Axes(0.125,0.511739;0.352273x0.167391)
# Price             Axes(0.547727,0.511739;0.352273x0.167391)
# House_floor           Axes(0.125,0.31087;0.352273x0.167391)
# building_floor     Axes(0.547727,0.31087;0.352273x0.167391)
# dtype: object

# %%
df.plot(kind='scatter', x='Price', y='House_floor', figsize=(4, 4))
# Out:
# <Axes: xlabel='Price', ylabel='House_floor'>

# %%
df.plot(kind='scatter', x='Price', y='Property_BHK', figsize=(4, 4))
# Out:
# <Axes: xlabel='Price', ylabel='Property_BHK'>

# %%
# @title Area_Range

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Area_Range').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Property_BHK vs Furnished_Status

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Furnished_Status'].value_counts()
    for x_label, grp in df.groupby('Property_BHK')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Property_BHK')
_ = plt.ylabel('Furnished_Status')

# %%
# @title Area_Range vs Area_sqft

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Area_Range'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Area_sqft', y='Area_Range', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df
# Out:
#       Area_sqft  Property_BHK Furnished_Status  Bathroom  \
# 7           392             1      Unfurnished         1
# 8           471             1      Unfurnished         1
# 9           525             1      Unfurnished         1
# 11          517             1      Unfurnished         1
# 13          645             1      Unfurnished         2
# ...         ...           ...              ...       ...
# 1495        723             2   Semi-Furnished         2
# 1496        403             1   Semi-Furnished         1
# 1497        454             1      Unfurnished         1
# 1498        491             1      Unfurnished         1
# 1499        299             1      Unfurnished         1
#
#                      Society  Price         Status  House_floor  \
# 7     Ishwar River Residency     32  Ready to Move           12
# 8           Kohinoor Majesty     21  Ready to Move            5
# 9      Sancheti Pratik Nagar     28  Ready to Move            1
# 11                   Blossom     35  Ready to Move            2
# 13                Raga Homes     37  Ready to Move           10
# ...                      ...    ...            ...          ...
# 1495          Tropical Palms     80  Ready to Move            1
# 1496         Lotus Apartment     30  Ready to Move            3
# 1497           Florida Minis     40  Ready to Move            2
# 1498          Swaraj Complex     32  Ready to Move            1
# 1499          Satyam Heights     22  Ready to Move            1
#
#       building_floor Price_Range    Area_Range
# 7                 12      30-60L  200-400 sqft
# 8                  9       0-30L  400-600 sqft
# 9                  3       0-30L  400-600 sqft
# 11                11      30-60L  400-600 sqft
# 13                11      30-60L  600-800 sqft
# ...              ...         ...           ...
# 1495              15      60-90L  600-800 sqft
# 1496               4      30-60L  400-600 sqft
# 1497               5      30-60L  400-600 sqft
# 1498               7      30-60L  400-600 sqft
# 1499               3       0-30L  200-400 sqft
#
# [1420 rows x 11 columns]

# %%
def categorize_floor(floor):
    if 1 <= floor <= 5:
        return 'Low Floor'
    elif 6 <= floor <= 15:
        return 'Mid Floor'
    elif floor > 15:
        return 'High Floor'
    else:
        return 'Unknown'
df['Price_per_sqft'] = df['Price'] / df['Area_sqft']
display(df.head())
display(df[['Floor_Level', 'Price_per_sqft']].describe(include='all'))
# Out:
#     Area_sqft  Property_BHK Furnished_Status  Bathroom  \
# 7         392             1      Unfurnished         1
# 8         471             1      Unfurnished         1
# 9         525             1      Unfurnished         1
# 11        517             1      Unfurnished         1
# 13        645             1      Unfurnished         2
#
#                    Society  Price         Status  House_floor  building_floor  \
# 7   Ishwar River Residency     32  Ready to Move           12              12
# 8         Kohinoor Majesty     21  Ready to Move            5               9
# 9    Sancheti Pratik Nagar     28  Ready to Move            1               3
# 11                 Blossom     35  Ready to Move            2              11
# 13              Raga Homes     37  Ready to Move           10              11
#
#    Price_Range    Area_Range Floor_Level  Price_per_sqft
# 7       30-60L  200-400 sqft   Mid Floor        0.081633
# 8        0-30L  400-600 sqft   Low Floor        0.044586
# 9        0-30L  400-600 sqft   Low Floor        0.053333
# 11      30-60L  400-600 sqft   Low Floor        0.067698
# 13      30-60L  600-800 sqft   Mid Floor        0.057364
#        Floor_Level  Price_per_sqft
# count         1420     1420.000000
# unique           2             NaN
# top      Low Floor             NaN
# freq          1068             NaN
# mean           NaN        0.086442
# std            NaN        0.034404
# min            NaN        0.033003
# 25%            NaN        0.064815
# 50%            NaN        0.081645
# 75%            NaN        0.099724
# max            NaN        0.493827

# %%
display(df.describe())
# Out:
#          Area_sqft  Property_BHK     Bathroom        Price  House_floor  \
# count  1420.000000   1420.000000  1420.000000  1420.000000  1420.000000
# mean    595.366197      1.657746     1.645070    53.607042     4.003521
# std     233.157500      0.672455     0.645424    42.415216     2.755350
# min      87.000000      0.000000     1.000000    10.000000     1.000000
# 25%     436.000000      1.000000     1.000000    32.000000     2.000000
# 50%     553.500000      2.000000     2.000000    44.000000     3.000000
# 75%     695.250000      2.000000     2.000000    62.000000     5.000000
# max    3096.000000      6.000000     6.000000   600.000000    14.000000
#
#        building_floor
# count     1420.000000
# mean         7.668310
# std          4.373568
# min          1.000000
# 25%          5.000000
# 50%          7.000000
# 75%         11.000000
# max         80.000000

# %%
display(df.dtypes)
# Out:
# Area_sqft            int64
# Property_BHK         int64
# Furnished_Status    object
# Bathroom             int64
# Society             object
# Price                int64
# Status              object
# House_floor          int64
# building_floor       int64
# Price_Range         object
# Area_Range          object
# dtype: object

# %%
plt.figure(figsize=(6, 4))
df['Furnished_Status'].value_counts().plot(kind='bar', color='coral')
plt.title('Furnishing Status Distribution')
plt.ylabel('Number of Properties')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(6, 4))
df['Area_Range'].value_counts().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.title('Area Range Distribution')
plt.xlabel('Number of Properties')
plt.ylabel('Area Range')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
df.hist(figsize=(10, 10))
plt.suptitle('Histograms of Numerical Features', y=1.02)
plt.tight_layout()
plt.show()

df.boxplot(figsize=(10, 10))
plt.suptitle('Box Plots of Numerical Features', y=1.02)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.heatmap(df[['Price', 'Area_sqft', 'Property_BHK', 'Bathroom', 'House_floor', 'building_floor']].corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Area_sqft', y='Price', hue='Price_Range', palette='coolwarm')
plt.title('Area vs. Price by Price Range')
plt.xlabel('Area (sqft)')
plt.ylabel('Price (Lakh ₹)')
plt.legend(title='Price Range', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

from pandas.api.types import CategoricalDtype
price_range_order = [
    '0-30L', '30-60L', '60-90L', '90-120L', '120-150L', '150-180L',
    '180-210L', '210-240L', '240-270L', '270-300L', '280L+'
]
price_cat = CategoricalDtype(categories=price_range_order, ordered=True)
df['Price_Range'] = df['Price_Range'].astype(price_cat)

plt.figure(figsize=(7, 4))
sns.boxplot(data=df, x='Bathroom', y='Price_Range', palette='muted')
plt.title('Price Range vs. Number of Bathrooms')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Price Range')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='Furnished_Status', y='Price', palette='pastel', estimator='mean')
plt.title('Average Price by Furnishing Status')
plt.xticks(rotation=45)
plt.ylabel('Average Price (Lakh ₹)')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Furnished_Status'].value_counts()
    for x_label, grp in df.groupby('Property_BHK')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Property_BHK')
_ = plt.ylabel('Furnished_Status')
plt.show()

figsize = (12, 1.2 * len(df['Area_Range'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Area_sqft', y='Area_Range', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
plt.show()
