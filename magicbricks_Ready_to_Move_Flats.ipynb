# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import pandas as pd
import time


base_url = 'https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs'
headers = {
    'Content-Type': 'text/html; charset=UTF-8',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Encoding': 'gzip, deflate, br'
}

all_data = {
    'Area': [],
    'Property': [],
    'Furnished Status': [],
    'Bathroom': [],
    'Society': [],
    'Price': [],
    'Floor': [],
    'Status': []
}

num_pages = 50
for page in range(1, num_pages + 1):
    url = f"{base_url}?page={page}" if page > 1 else base_url
    print(f"Scraping page {page}: {url}")
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  
        soup = BeautifulSoup(response.text, 'html.parser')
        sections = soup.find_all('div', class_='mb-srp__list')
        
        if not sections:
            print(f"No listings found on page {page}. Stopping.")
            break
        
        for section in sections:
            text = section.get_text(separator=" ", strip=True)
            if page == 1 and len(all_data['Area']) == 0:
                print("Sample raw text for first listing:", text[:500] + "...")
            
            # Area
            area = re.findall(r"Area\s*(\d+\.?\d*)\s*sqft", text)
            all_data['Area'].append(area[0] if area else np.nan)
            
            # Property Type
            prop_type = re.findall(r"(\d BHK)", text)
            all_data['Property'].append(prop_type[0] if prop_type else np.nan)
            
            # Furnished Status
            furnishing = re.findall(r"Furnishing\s*(Furnished|Semi-Furnished|Unfurnished)\s*(?=Society|Bathroom|Carpet|$)", text)
            all_data['Furnished Status'].append(furnishing[0] if furnishing else np.nan)
            
            # Bathroom
            bathroom = re.findall(r"Bathroom\s*(\d)", text)
            all_data['Bathroom'].append(f"Bathroom {bathroom[0]}" if bathroom else np.nan)
            
            # Society
            society = re.findall(r"Society\s*([A-Za-z0-9\s]+?)(?=\s*(?:Ownership|Bathroom|Car Parking|$))", text)
            all_data['Society'].append(society[0].strip() if society else np.nan)
            price = re.findall(r"₹\s*(\d+\.?\d*\s*(?:Lac|Cr))", text)
            all_data['Price'].append(price[0] if price else np.nan)
            if not price:
                print(f"No price found for listing on page {page}: {text[:200]}...")

            
            # Floor
            floor = re.findall(r"Floor\s*(Ground|\d+)\s*out\s*of\s*(\d+)", text)
            all_data['Floor'].append(f"{floor[0][0]} out of {floor[0][1]}" if floor else np.nan)
            
            # Status
            status = re.findall(r"Status\s*(Ready to Move|Under Construction|New Launch)", text)
            all_data['Status'].append(status[0] if status else np.nan)
        print(f"Page {page} scraped successfully. Found {len(sections)} listings.")
        time.sleep(2)  
    
    except requests.RequestException as e:
        print(f"Error scraping page {page}: {e}")
        continue

# Create a DataFrame from the collected data
df = pd.DataFrame(all_data)

# Display the DataFrame
print("\nDataFrame Preview:")
print(df.head())
print(f"\nTotal listings scraped: {len(df)}")

# Save the DataFrame to a CSV file
df.to_csv('magicbricks_Ready_to_Move_Flats_50_Pages.csv', index=False)
print(f"Data saved to 'magicbricks_Ready_to_Move_Flats_50_Pages.csv' with {len(df)} listings.")
# Out:
# Scraping page 1: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs
# Sample raw text for first listing: 13 + Photos Posted: May 29, '25 Builder: Sudarshan Group 2 BHK Ready to Occupy Flat for sale in Sudarshan Paradise Pimple Nilakh, Pimpri Chinchwad Sudarshan Paradise Carpet Area 807 sqft Status Ready to Move Transaction New Property Furnishing Unfurnished Society Sudarshan Paradise Car Parking 1 Covered, Bathroom 2 The modern amenities provided by this society will surely offer you a high class lifestyle with your beloved family members 2 BHK flat is offered for sale in Pimple Nilakh, Pune. It h...
# Page 1 scraped successfully. Found 30 listings.
# Scraping page 2: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=2
# Page 2 scraped successfully. Found 30 listings.
# Scraping page 3: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=3
# Page 3 scraped successfully. Found 30 listings.
# Scraping page 4: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=4
# Page 4 scraped successfully. Found 30 listings.
# Scraping page 5: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=5
# Page 5 scraped successfully. Found 30 listings.
# Scraping page 6: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=6
# Page 6 scraped successfully. Found 30 listings.
# Scraping page 7: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=7
# Page 7 scraped successfully. Found 30 listings.
# Scraping page 8: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=8
# Page 8 scraped successfully. Found 30 listings.
# Scraping page 9: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=9
# Page 9 scraped successfully. Found 30 listings.
# Scraping page 10: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=10
# Page 10 scraped successfully. Found 30 listings.
# Scraping page 11: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=11
# Page 11 scraped successfully. Found 30 listings.
# Scraping page 12: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=12
# Page 12 scraped successfully. Found 30 listings.
# Scraping page 13: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=13
# Page 13 scraped successfully. Found 30 listings.
# Scraping page 14: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=14
# Page 14 scraped successfully. Found 30 listings.
# Scraping page 15: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=15
# Page 15 scraped successfully. Found 30 listings.
# Scraping page 16: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=16
# Page 16 scraped successfully. Found 30 listings.
# Scraping page 17: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=17
# Page 17 scraped successfully. Found 30 listings.
# Scraping page 18: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=18
# Page 18 scraped successfully. Found 30 listings.
# Scraping page 19: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=19
# Page 19 scraped successfully. Found 30 listings.
# Scraping page 20: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=20
# Page 20 scraped successfully. Found 30 listings.
# Scraping page 21: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=21
# Page 21 scraped successfully. Found 30 listings.
# Scraping page 22: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=22
# Page 22 scraped successfully. Found 30 listings.
# Scraping page 23: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=23
# Page 23 scraped successfully. Found 30 listings.
# Scraping page 24: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=24
# Page 24 scraped successfully. Found 30 listings.
# Scraping page 25: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=25
# Page 25 scraped successfully. Found 30 listings.
# Scraping page 26: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=26
# Page 26 scraped successfully. Found 30 listings.
# Scraping page 27: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=27
# Page 27 scraped successfully. Found 30 listings.
# Scraping page 28: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=28
# Page 28 scraped successfully. Found 30 listings.
# Scraping page 29: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=29
# Page 29 scraped successfully. Found 30 listings.
# Scraping page 30: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=30
# Page 30 scraped successfully. Found 30 listings.
# Scraping page 31: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=31
# Page 31 scraped successfully. Found 30 listings.
# Scraping page 32: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=32
# Page 32 scraped successfully. Found 30 listings.
# Scraping page 33: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=33
# Page 33 scraped successfully. Found 30 listings.
# Scraping page 34: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=34
# Page 34 scraped successfully. Found 30 listings.
# Scraping page 35: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=35
# Page 35 scraped successfully. Found 30 listings.
# Scraping page 36: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=36
# Page 36 scraped successfully. Found 30 listings.
# Scraping page 37: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=37
# Page 37 scraped successfully. Found 30 listings.
# Scraping page 38: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=38
# Page 38 scraped successfully. Found 30 listings.
# Scraping page 39: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=39
# Page 39 scraped successfully. Found 30 listings.
# Scraping page 40: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=40
# Page 40 scraped successfully. Found 30 listings.
# Scraping page 41: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=41
# Page 41 scraped successfully. Found 30 listings.
# Scraping page 42: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=42
# Page 42 scraped successfully. Found 30 listings.
# Scraping page 43: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=43
# Page 43 scraped successfully. Found 30 listings.
# Scraping page 44: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=44
# Page 44 scraped successfully. Found 30 listings.
# Scraping page 45: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=45
# Page 45 scraped successfully. Found 30 listings.
# Scraping page 46: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=46
# Page 46 scraped successfully. Found 30 listings.
# Scraping page 47: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=47
# Page 47 scraped successfully. Found 30 listings.
# Scraping page 48: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=48
# Page 48 scraped successfully. Found 30 listings.
# Scraping page 49: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=49
# Page 49 scraped successfully. Found 30 listings.
# Scraping page 50: https://www.magicbricks.com/ready-to-move-flats-in-pune-pppfs?page=50
# Page 50 scraped successfully. Found 30 listings.
#
# DataFrame Preview:
#   Area Property Furnished Status    Bathroom                       Society  \
# 0  807    2 BHK      Unfurnished  Bathroom 2            Sudarshan Paradise
# 1  973    3 BHK      Unfurnished  Bathroom 3  Shapoorji Pallonji Sensorium
# 2  640    2 BHK              NaN  Bathroom 2                  Forest Hills
# 3  894    2 BHK              NaN  Bathroom 2                Kundan Espacio
# 4  560    1 BHK              NaN  Bathroom 1            Tarangan Apartment
#
#      Price        Floor         Status
# 0   65 Lac          NaN  Ready to Move
# 1  1.32 Cr          NaN            NaN
# 2   37 Lac   7 out of 7  Ready to Move
# 3  1.20 Cr  3 out of 13  Ready to Move
# 4   90 Lac   2 out of 3  Ready to Move
#
# Total listings scraped: 1500
# Data saved to 'magicbricks_Ready_to_Move_Flats_50_Pages.csv' with 1500 listings.
